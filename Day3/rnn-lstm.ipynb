# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, LSTM, Dense

# Load and preprocess the data
with open('D:/Basudev/genaiprereq/Day2/poetry.txt', 'r') as file:
    text = file.read().lower()

# Tokenize the text
tokenizer = Tokenizer()
tokenizer.fit_on_texts([text])
total_words = len(tokenizer.word_index) + 1
input_sequences = []

# Create input sequences
for line in text.split('\n'):
    token_list = tokenizer.texts_to_sequences([line])[0]
    for i in range(1, len(token_list)):
        n_gram_sequence = token_list[:i+1]
        input_sequences.append(n_gram_sequence)

# Pad sequences and create predictors and labels
max_sequence_len = max([len(x) for x in input_sequences])
input_sequences = np.array(pad_sequences(input_sequences, maxlen=max_sequence_len, padding='pre'))
X = input_sequences[:,:-1]
y = input_sequences[:,-1]
y = to_categorical(y, num_classes=total_words)

# Define an LSTM model
def create_lstm_model():
    model = Sequential()
    model.add(Embedding(total_words, 64, input_length=max_sequence_len-1))
    model.add(LSTM(128))  # Increased units for improved learning
    model.add(Dense(total_words, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# Create and train LSTM model
lstm_model = create_lstm_model()
lstm_model.fit(X, y, epochs=150, verbose=1)  # Increased epochs

# Text generation function with temperature sampling
def generate_text(seed_text, next_words, model, max_sequence_len, temperature=0.7):
    for _ in range(next_words):
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=max_sequence_len-1, padding='pre')
        
        # Predict with temperature
        predictions = model.predict(token_list, verbose=0)
        predictions = np.asarray(predictions).astype("float64")
        predictions = np.log(predictions + 1e-10) / temperature  # Apply temperature
        exp_preds = np.exp(predictions)
        predictions = exp_preds / np.sum(exp_preds)
        
        # Sample the next word index
        predicted = np.random.choice(range(total_words), p=predictions[0])
        
        # Convert predicted index to word
        output_word = tokenizer.index_word.get(predicted, "")
        seed_text += " " + output_word
    return seed_text

# Generate text with temperature sampling
seed_text = "The woods are lovely"
output_text = generate_text(seed_text, next_words=10, model=lstm_model, max_sequence_len=max_sequence_len, temperature=0.8)
print("Generated text:", output_text)
# Out:
# Epoch 1/150
# 6/6 [==============================] - 2s 14ms/step - loss: 4.8976 - accuracy: 0.0333
# Epoch 2/150
# 6/6 [==============================] - 0s 12ms/step - loss: 4.8806 - accuracy: 0.0722
# Epoch 3/150
# 6/6 [==============================] - 0s 10ms/step - loss: 4.8551 - accuracy: 0.0889
# Epoch 4/150
# 6/6 [==============================] - 0s 12ms/step - loss: 4.7853 - accuracy: 0.0722
# Epoch 5/150
# 6/6 [==============================] - 0s 11ms/step - loss: 4.6363 - accuracy: 0.0611
# Epoch 6/150
# 6/6 [==============================] - 0s 10ms/step - loss: 4.6363 - accuracy: 0.0556
# Epoch 7/150
# 6/6 [==============================] - 0s 9ms/step - loss: 4.5976 - accuracy: 0.0556
# Epoch 8/150
# 6/6 [==============================] - 0s 9ms/step - loss: 4.5885 - accuracy: 0.0556
# Epoch 9/150
# 6/6 [==============================] - 0s 9ms/step - loss: 4.5533 - accuracy: 0.0556
# Epoch 10/150
# 6/6 [==============================] - 0s 8ms/step - loss: 4.5296 - accuracy: 0.0556
# Epoch 11/150
# 6/6 [==============================] - 0s 13ms/step - loss: 4.5110 - accuracy: 0.0556
# Epoch 12/150
# 6/6 [==============================] - 0s 12ms/step - loss: 4.4863 - accuracy: 0.0556
# Epoch 13/150
# 6/6 [==============================] - 0s 8ms/step - loss: 4.4566 - accuracy: 0.0556
# Epoch 14/150
# 6/6 [==============================] - 0s 10ms/step - loss: 4.4176 - accuracy: 0.0667
# Epoch 15/150
# 6/6 [==============================] - 0s 9ms/step - loss: 4.3651 - accuracy: 0.0667
# Epoch 16/150
# 6/6 [==============================] - 0s 9ms/step - loss: 4.2805 - accuracy: 0.1056
# Epoch 17/150
# 6/6 [==============================] - 0s 8ms/step - loss: 4.2042 - accuracy: 0.1222
# Epoch 18/150
# 6/6 [==============================] - 0s 10ms/step - loss: 4.
# 6/6 [==============================] - 0s 8ms/step - loss: 1.8987 - accuracy: 0.6111
# Epoch 46/150
# 6/6 [==============================] - 0s 10ms/step - loss: 1.8609 - accuracy: 0.6167
# Epoch 47/150
# 6/6 [==============================] - 0s 9ms/step - loss: 1.7993 - accuracy: 0.6111
# Epoch 48/150
# 6/6 [==============================] - 0s 10ms/step - loss: 1.7401 - accuracy: 0.6444
# Epoch 49/150
# 6/6 [==============================] - 0s 11ms/step - loss: 1.6873 - accuracy: 0.6500
# Epoch 50/150
# 6/6 [==============================] - 0s 9ms/step - loss: 1.6337 - accuracy: 0.6389
# Epoch 51/150
# 6/6 [==============================] - 0s 8ms/step - loss: 1.6017 - accuracy: 0.6722
# Epoch 52/150
# 6/6 [==============================] - 0s 11ms/step - loss: 1.5896 - accuracy: 0.6778
# Epoch 53/150
# 6/6 [==============================] - 0s 8ms/step - loss: 1.5185 - accuracy: 0.7222
# Epoch 54/150
# 6/6 [==============================] - 0s 8ms/step - loss: 1.4858 - accuracy: 0.6889
# Epoch 55/150
# 6/6 [==============================] - 0s 8ms/step - loss: 1.4547 - accuracy: 0.7667
# Epoch 56/150
# 6/6 [==============================] - 0s 18ms/step - loss: 1.4303 - accuracy: 0.6500
# Epoch 57/150
# 6/6 [==============================] - 0s 7ms/step - loss: 1.3760 - accuracy: 0.7667
# Epoch 58/150
# 6/6 [==============================] - 0s 10ms/step - loss: 1.3328 - accuracy: 0.7556
# Epoch 59/150
# 6/6 [==============================] - 0s 10ms/step - loss: 1.3099 - accuracy: 0.7278
# Epoch 60/150
# 6/6 [==============================] - 0s 9ms/step - loss: 1.2686 - accuracy: 0.8000
# Epoch 61/150
# 6/6 [==============================] - 0s 11ms/step - loss: 1.2274 - accuracy: 0.7944
# Epoch 62/150
# 6/6 [==============================] - 0s 9ms/step - loss: 1.1827 - accuracy: 0.8278
# Epoch 63/150
# 6/6 [==============================] - 0s 10ms/step - loss: 1.1457 - accuracy: 0.8278
# Epoch 64/150
# 6/6 [==============================] - 0s 8ms/step - loss: 1.1131 - accuracy: 0.8222
# Epoch 65/150
# 6/6 [==============================] - 0s 9ms/step - loss: 1.0894 - accuracy: 0.8500
# Epoch 66/150
# 6/6 [==============================] - 0s 9ms/step - loss: 1.0554 - accuracy: 0.8444
# Epoch 67/150
# 6/6 [==============================] - 0s 9ms/step - loss: 1.0244 - accuracy: 0.8611
# Epoch 68/150
# 6/6 [==============================] - 0s 9ms/step - loss: 0.9942 - accuracy: 0.8778
# Epoch 69/150
# 6/6 [==============================] - 0s 9ms/step - loss: 0.9716 - accuracy: 0.8833
# Epoch 70/150
# 6/6 [==============================] - 0s 9ms/step - loss: 0.9532 - accuracy: 0.8833
# Epoch 71/150
# 6/6 [==============================] - 0s 10ms/step - loss: 0.9321 - accuracy: 0.9111
# Epoch 72/150
# 6/6 [==============================] - 0s 10ms/step - loss: 0.9046 - accuracy: 0.8833
# Epoch 73/150
# 6/6 [==============================] - 0s 8ms/step - loss: 0.8763 - accuracy: 0.9222
# Epoch 74/150
# 6/6 [==============================] - 0s 13ms/step - loss: 0.8464 - accuracy: 0.9222
# Epoch 75/150
# 6/6 [==============================] - 0s 12ms/step - loss: 0.8269 - accuracy: 0.9333
# Epoch 76/150
# 6/6 [==============================] - 0s 9ms/step - loss: 0.8087 - accuracy: 0.9278
# Epoch 77/150
# 6/6 [==============================] - 0s 11ms/step - loss: 0.7797 - accuracy: 0.9333
# Epoch 78/150
# 6/6 [==============================] - 0s 9ms/step - loss: 0.7580 - accuracy: 0.9333
# Epoch 79/150
# 6/6 [==============================] - 0s 9ms/step - loss: 0.7417 - accuracy: 0.9333
# Epoch 80/150
# 6/6 [==============================] - 0s 20ms/step - loss: 0.7231 - accuracy: 0.9389
# Epoch 81/150
# 6/6 [==============================] - 0s 9ms/step - loss: 0.7023 - accuracy: 0.9389
# Epoch 82/150
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6884 - accuracy: 0.9333
# Epoch 83/150
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6745 - accuracy: 0.9333
# Epoch 84/150
# 6/6 [==============================] - 0s 9ms/step - loss: 0.6529 - accuracy: 0.9444
# Epoch 85/150
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6316 - accuracy: 0.9389
# Epoch 86/150
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6146 - accuracy: 0.9444
# Epoch 87/150
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6030 - accuracy: 0.9444
# Epoch 88/150
# 6/6 [==============================] - 0s 10ms/step - loss: 0.5898 - accuracy: 0.9444
# Epoch 89/150
# 6/6 [==============================] - 0s 9ms/step - loss: 0.5738 - accuracy: 0.9444
# Epoch 90/150
# 6/6 [==============================] - 0s 9ms/step - loss: 0.5569 - accuracy: 0.9500
# Epoch 91/150
# 6/6 [==============================] - 0s 9ms/step - loss: 0.5394 - accuracy: 0.9556
# Epoch 92/150
# 6/6 [==============================] - 0s 9ms/step - loss: 0.5276 - accuracy: 0.9611
# Epoch 93/150
# 6/6 [==============================] - 0s 9ms/step - loss: 0.5152 - accuracy: 0.9611
# Epoch 94/150
# 6/6 [==============================] - 0s 9ms/step - loss: 0.5066 - accuracy: 0.9611
# Epoch 95/150
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4909 - accuracy: 0.9611
# Epoch 96/150
# 6/6 [==============================] - 0s 11ms/step - loss: 0.4808 - accuracy: 0.9556
# Epoch 97/150
# 6/6 [==============================] - 0s 11ms/step - loss: 0.4714 - accuracy: 0.9611
# Epoch 98/150
# 6/6 [==============================] - 0s 11ms/step - loss: 0.4646 - accuracy: 0.9556
# Epoch 99/150
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4486 - accuracy: 0.9611
# Epoch 100/150
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4391 - accuracy: 0.9611
# Epoch 101/150
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4274 - accuracy: 0.9611
# Epoch 102/150
# 6/6 [==============================] - 0s 10ms/step - loss: 0.4195 - accuracy: 0.9611
# Epoch 103/150
# 6/6 [==============================] - 0s 20ms/step - loss: 0.4103 - accuracy: 0.9611
# Epoch 104/150
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4001 - accuracy: 0.9556
# Epoch 105/150
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3916 - accuracy: 0.9611
# Epoch 106/150
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3838 - accuracy: 0.9611
# Epoch 107/150
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3778 - accuracy: 0.9556
# Epoch 108/150
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3701 - accuracy: 0.9611
# Epoch 109/150
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3607 - accuracy: 0.9611
# Epoch 110/150
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3520 - accuracy: 0.9611
# Epoch 111/150
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3446 - accuracy: 0.9611
# Epoch 112/150
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3385 - accuracy: 0.9556
# Epoch 113/150
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3311 - accuracy: 0.9611
# Epoch 114/150
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3259 - accuracy: 0.9556
# Epoch 115/150
# 6/6 [==============================] - 0s 14ms/step - loss: 0.3194 - accuracy: 0.9556
# Epoch 116/150
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3125 - accuracy: 0.9556
# Epoch 117/150
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3069 - accuracy: 0.9611
# Epoch 118/150
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3009 - accuracy: 0.9611
# Epoch 119/150
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2974 - accuracy: 0.9611
# Epoch 120/150
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2922 - accuracy: 0.9611
# Epoch 121/150
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2861 - accuracy: 0.9611
# Epoch 122/150
# 6/6 [==============================] - 0s 10ms/step - loss: 0.2823 - accuracy: 0.9611
# Epoch 123/150
# 6/6 [==============================] - 0s 10ms/step - loss: 0.2776 - accuracy: 0.9611
# Epoch 124/150
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2756 - accuracy: 0.9611
# Epoch 125/150
# 6/6 [==============================] - 0s 21ms/step - loss: 0.2694 - accuracy: 0.9611
# Epoch 126/150
# 6/6 [==============================] - 0s 10ms/step - loss: 0.2667 - accuracy: 0.9556
# Epoch 127/150
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2610 - accuracy: 0.9611
# Epoch 128/150
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2559 - accuracy: 0.9611
# Epoch 129/150
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2526 - accuracy: 0.9611
# Epoch 130/150
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2492 - accuracy: 0.9611
# Epoch 131/150
# 6/6 [==============================] - 0s 10ms/step - loss: 0.2449 - accuracy: 0.9611
# Epoch 132/150
# 6/6 [==============================] - 0s 10ms/step - loss: 0.2423 - accuracy: 0.9556
# Epoch 133/150
# 6/6 [==============================] - 0s 12ms/step - loss: 0.2377 - accuracy: 0.9611
# Epoch 134/150
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2356 - accuracy: 0.9611
# Epoch 135/150
# 6/6 [==============================] - 0s 10ms/step - loss: 0.2315 - accuracy: 0.9611
# Epoch 136/150
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2296 - accuracy: 0.9556
# Epoch 137/150
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2268 - accuracy: 0.9611
# Epoch 138/150
# 6/6 [==============================] - 0s 10ms/step - loss: 0.2238 - accuracy: 0.9611
# Epoch 139/150
# 6/6 [==============================] - 0s 10ms/step - loss: 0.2201 - accuracy: 0.9611
# Epoch 140/150
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2173 - accuracy: 0.9611
# Epoch 141/150
# 6/6 [==============================] - 0s 10ms/step - loss: 0.2152 - accuracy: 0.9611
# Epoch 142/150
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2126 - accuracy: 0.9611
# Epoch 143/150
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2097 - accuracy: 0.9611
# Epoch 144/150
# 6/6 [==============================] - 0s 10ms/step - loss: 0.2086 - accuracy: 0.9556
# Epoch 145/150
# 6/6 [==============================] - 0s 10ms/step - loss: 0.2055 - accuracy: 0.9611
# Epoch 146/150
# 6/6 [==============================] - 0s 10ms/step - loss: 0.2022 - accuracy: 0.9611
# Epoch 147/150
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2006 - accuracy: 0.9611
# Epoch 148/150
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1982 - accuracy: 0.9611
# Epoch 149/150
# 6/6 [==============================] - 0s 10ms/step - loss: 0.1971 - accuracy: 0.9611
# Epoch 150/150
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1952 - accuracy: 0.9556
# Generated text: The woods are lovely dark and deep loreâ€” winds tune perches loreâ€” short my
